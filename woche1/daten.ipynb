# %% [markdown]
# # Daten aggregieren
#
# In diesem Notebook lernen wir einige der geläufigsten Methoden und Kennzahlen zur Aggregation von Daten kennen.
#
# Lernziele:
#
# * Sie nennen einige Aggregationsmethoden, um grössere Datenmengen knapp zusammenzufassen. Eine Auswahl davon können Sie auch selbst implementieren
# * Sie können eine Vielzahl von Kennzahlen nennen und ihre Bedeutung erklären. Mithilfe von importierten Funktionen aus Paketen wie `pandas` und `numpy` können sie diese auch in Python berechnen. Dazu gehören Minimum/Maximum, Durchschnitt, Varianz, Standardabweichung, Korrelationskoeffizient.

# %% [markdown]
# ### Aufgabe 1: Vervollständigen Sie die Funktion `mean` und testen Sie sie mit den beiden Listen `noten_klasse_a` und `noten_klasse_b`.

# %%
noten_klasse_a = [3, 5.5, 4, 6, 2.5, 3, 6, 5.5, 4, 3, 4.5, 3, 3, 4, 6, 5.5, 6]
noten_klasse_b = [4, 5.5, 4, 4, 3.5, 4, 5, 5.5, 4, 4, 4.5, 4, 4, 4, 5, 5, 4.5]

def mean(liste):
    ### Dein Code hier:
    ...

# %% [markdown]
# Führen Sie die folgende Zelle zunächst ohne Veränderungen aus.
# Besprechen Sie mit Ihrem Sitznachbarn, was Ihenen bei den beiden Notenverteilungen auffällt.

# %%
from matplotlib import pyplot as plt

plt.hist(noten_klasse_a, color=(0.1, 0.2, 0.5, 0.3), label="Klasse A", bins=np.linspace(2.25, 6.25, 9), rwidth=0.7)
plt.hist(noten_klasse_b, color=(1, 0.2, 0.1, 0.3), label="Klasse B", bins=np.linspace(2.25, 6.25, 9), rwidth=0.7)
plt.xlabel("Note")
plt.ylabel("Anzahl")
plt.legend()
plt.title

# %% [markdown]
# ### Aufgabe 2: Vervollständigen Sie die Funktion `variance` entsprechend der Instruktionen an der Tafel

# %%
def variance(liste):
    # Ihr Code hier:
    ...
    durchschnitt = ...
    for element in liste:
        ...
